# %%
# Cat Savage
# Training Set Vs. Test Set Sizes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.optimize import curve_fit

# %%
# Periodic Table
# Signs of electron affinity values swapped
# courtesy of Penn State CS professor Doug Hogan

# %%
element_dat = pd.read_csv( 'https://github.com/adamlamee/CODINGinK12/raw/master/data/elements.csv' )

# %%
element_dat.shape
# number of rows, number of columns
# Out:
# (118, 20)

# %%
element_tr  = element_dat[ element_dat.index % 5 == 0 ]
element_tst = element_dat[ element_dat.index % 5 != 0 ]

# %%
# note to self:
# element_tr takes all rows w indices of 0, 5, 10, (any number divisible by 5), and keeps it
# element_tst keeps the rest of the rows (the ones NOT divisible by 5)
# modulus number doesn't always have to be 5, just went with what Adam gave in his example

# %%
element_tr.shape
# Out:
# (24, 20)

# %%
element_tst.shape
# Out:
# (94, 20)

# %%
# scatterplot
plt.scatter( element_tr['Ionization Energy (kJ/mol)'], element_tr['Electron Affinity (kJ/mol)'] )
plt.show( )

# %%
# scatterplot
plt.scatter( element_tr['Electronegativity'], element_tr['Ionization Energy (kJ/mol)'] )

plt.title( 'Element Training Set' )

plt.xlabel( 'Electronegativity' )
plt.ylabel( 'Ionization Energy, kJ/mol' )

# plt.xlim( -0.5, 3.0 )
# plt.ylim( 0, 1400 )

plt.show( )
# will clean up later ( 5/18/2025, 7:04 PM )

# %%
# this one looks kind of better than the first one

# %%
# scatterplot
plt.scatter( element_tst['Electronegativity'], element_tst['Ionization Energy (kJ/mol)'] )

plt.title( 'Element Testing Set' )

plt.xlabel( 'Electronegativity' )
plt.ylabel( 'Ionization Energy, kJ/mol' )

# plt.xlim( -0.5, 3.0 )
# plt.ylim( 0, 1400 )

plt.show( )
# will clean up later ( 5/18/2025, 7:12 PM )

# %%
# scatterplot
# plt.scatter( element_tr['Electronegativity'], element_tr['Ionization Energy (kJ/mol)'] )

# plt.title( 'Element Training Sets' )

# plt.xlabel( 'Electronegativity' )
# plt.ylabel( 'Ionization Energy, kJ/mol' )

# plt.xlim( -0.5, 3.0 )
# plt.ylim( 0, 1600 )

# plt.show( )
